# %% [markdown]
# # Multi-Agent Research Assistant — Exploration Notebook
#
# Use this notebook for interactive experimentation with the agents and graph.

# %%
import sys
sys.path.insert(0, '..')

from dotenv import load_dotenv
load_dotenv()

from src.config.settings import get_settings
settings = get_settings()
print(f'Supervisor model: {settings.supervisor_model}')
print(f'Agent model: {settings.agent_model}')

# %%
from src.graph.state import create_initial_state
from src.graph.workflow import create_research_graph

graph = create_research_graph()
state = create_initial_state('What is quantum computing?')
# result = graph.invoke(state)
